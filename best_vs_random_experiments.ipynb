# %%
from custom_pool import CustomPool

# %%
runs = 20

# %%
def experiment_fn():
    from run import experiment
    
    params = {
        "model": "CNNModel3",
        "states": 5,
        "symbols": 5,
        "gens": 50,
        "mut_fn": "uniform",
        "_random_search": True,
        "_pool_size": 8,
    }
    
    exp_data = experiment(params, runs)
    
    return exp_data

# %%
exp_results = experiment_fn()
# Out:
# Using TensorFlow backend.
# Run 1
# {'model': 'CNNModel3', 'states': 5, 'symbols': 5, 'epochs': 10, 'epoch_size': 500, 'batch_size': 200, 'seq_len': 20, 'pop_size': 25, 'gens': 50, 'offspring_prop': 1.0, 'cx_prob': 0.0, 'mut_fn': 'uniform', 'mut_prob': 1.0, 'mut_rate': None, '_pool_size': 8, '_random_search': True}
# Pre-training discriminator...
# Pre-trained discriminiator accuracy: 0.8862299919128418
# Running generator...
# gen	nevals	mean    	min
# 0  	25    	0.835245	0.64
# 1  	50    	0.8236  	0.69
# 2  	50    	0.8016  	0.695
# 3  	50    	0.7772  	0.7
# 4  	50    	0.7726  	0.685
# 5  	50    	0.7474  	0.69
# 6  	50    	0.75    	0.64
# 7  	50    	0.7448  	0.665
# 8  	50    	0.7322  	0.67
# 9  	50    	0.7416  	0.7
# 10 	50    	0.7002  	0.615
# 11 	50    	0.7082  	0.61
# 12 	50    	0.7078  	0.64
# 13 	50    	0.6822  	0.63
# 14 	50    	0.699   	0.66
# 15 	50    	0.6798  	0.625
# 16 	50    	0.7034  	0.64
# 17 	50    	0.6908  	0.645
# 18 	50    	0.6612  	0.62
# ...
