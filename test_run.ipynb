# %%
import run
# Out:
# Using TensorFlow backend.

# %%
params = {
    "states": 3,
    "symbols": 5,
    "epochs": 10,
    "epoch_size": 500,
    "batch_size": 200,
    "seq_len": 20,
    "pool_size": 8,
    "pop_size": 50,
    "gens": 50,
    "offspring_prop": 0.25,
    "cx_prob": 0.0,
    "mut_prob": 1.0,
}
# Default

# %%
runs = 5

best_l2s = []
rand_l2s = []

for i in range (runs):
    print(f"Run {i+1}")
    real_hmm, best_hmm, best_l2, rand_l2, logbook = run.run(params)
    best_l2s.append(best_l2)
    rand_l2s.append(rand_l2)
    print(f"Best L2 = {best_l2}, Rand L2 = {rand_l2}")
# Out:
# Run 1
# {'states': 3, 'symbols': 5, 'epochs': 10, 'epoch_size': 500, 'batch_size': 200, 'seq_len': 20, 'pool_size': 8, 'pop_size': 50, 'gens': 50, 'offspring_prop': 0.25, 'cx_prob': 0.0, 'mut_prob': 1.0}
# Epoch 1/10
# 500/500 [==============================] - 10s 20ms/step - loss: 0.3195 - accuracy: 0.8636
# Epoch 2/10
# 500/500 [==============================] - 9s 19ms/step - loss: 0.2686 - accuracy: 0.8852
# Epoch 3/10
# 500/500 [==============================] - 9s 18ms/step - loss: 0.2614 - accuracy: 0.8892
# Epoch 4/10
# Epoch 3/10
# 500/500 [==============================] - 9s 19ms/step - loss: 0.2426 - accuracy: 0.8970
# Epoch 5/10
# Epoch 4/10
# 500/500 [==============================] - 9s 19ms/step - loss: 0.2392 - accuracy: 0.8980
# Epoch 6/10
# Epoch 5/10
# 500/500 [==============================] - 9s 18ms/step - loss: 0.2418 - accuracy: 0.8979
# Epoch 7/10
# 500/500 [==============================] - 9s 18ms/step - loss: 0.2381 - accuracy: 0.8992
# Epoch 8/10
# ...

# %%
best_l2s
# Out:
# [3.1693513406627085,
#  3.030521167221519,
#  2.556861004890878,
#  1.930401791868971,
#  2.9575559161899525]

# %%
rand_l2s
# Out:
# [3.5769656184349206,
#  3.761592388203325,
#  3.277269239766043,
#  3.4753606339534158,
#  3.996982451665847]
